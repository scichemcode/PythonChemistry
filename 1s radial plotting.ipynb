# %%
import matplotlib.pyplot as plt
import numpy as np

r=np.arange(0,1.5,0.01)
rdf=2/(0.594)**(3/2)*np.exp(-r/0.594)
prob=(rdf)**2*r**2
fig,axs=plt.subplots(2)
axs[0].plot(r,rdf)
axs[0].set_title('1s wave function')
axs[1].plot(r,prob,label='Probability Plot')
plt.legend()
